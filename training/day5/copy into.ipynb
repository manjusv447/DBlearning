# %%
# %sql
create table dev.manju.sales_b as 
select * from read_files ("/Volumes/dev/naval/project/sales/sales.csv")

# %%
# %sql
create or replace table dev.manju.sales_b as 
select * from read_files ("/Volumes/dev/naval/project/sales/")

# %%
# %sql
select * from dev.naval.sales_b

# %%
# %sql
create table if not exists dev.manju.sales_copy (order_id int, customer_id int , transaction_id int, product_id int, quantity int, discount_amount double, total_amount double, order_date string)

# %%
# %sql
create table if not exists dev.manju.month_copy

# %%
# %sql
COPY INTO dev.manju.month_copy 
FROM '/Volumes/dev/naval/project/incremental/'
FILEFORMAT = CSV
FORMAT_OPTIONS ('header' = 'true')
COPY_OPTIONS ('mergeSchema' = 'true');
