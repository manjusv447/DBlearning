# %%
# %sql
create schema dev.manju;

# %%
# %sql
create table dev.manju.demo;

# %%
# %sql

# %%
# %sql
select * from dev.manju.demo

# %%
# %sql

# %% [markdown]
# ![](/Volumes/dev/naval/raw/object-model.png)

# %% [markdown]
# ![](/Volumes/dev/naval/raw/object-model.png)
