# %%
# %run "/Workspace/Users/manju.sv@allianz.com/training/day3/lakehouse, delta lake/includes"

# %%
dbutils.widgets.text("catalog","dev")
dbutils.widgets.text("table_name","sales")

# %%
catalog=dbutils.widgets.get("catalog")
table_name=dbutils.widgets.get("table_name")

# %%
df=(spark.read.csv(f"{input_path}{table_name}/",header=True,inferSchema=True))
df1=add_columns(df)
df1.write.mode("overwrite").saveAsTable(f"{catalog}.manju_bronze.{table_name}")
