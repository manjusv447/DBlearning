# %%
# %sql
create table dev.manju.employee (id int, name string) location 's3://jpmctraining/allianz/manju'

# %%
# %sql
select * from delta.`s3://jpmctraining/allianz/manju`

# %%
# %sql
CREATE OR REPLACE TABLE dev.manju.demo_clone_shallow
SHALLOW CLONE dev.manju.demo;

# %%
# %sql
CREATE OR REPLACE TABLE test_clone_deep
DEEP CLONE test_clone_source;


CREATE OR REPLACE TABLE test_clone_shallow
SHALLOW CLONE test_clone_source;
