# %%
same org: 
team 1:
    Azure databricks ( product1 ) -- 6-8 weeks 


team 2: 
    azure/AWS DAtabricks ( product 2)- 



notebooks (script)
data assestes (tables,view, volume, ml + ai models) 


Data sharing : linux + databricks == open source
