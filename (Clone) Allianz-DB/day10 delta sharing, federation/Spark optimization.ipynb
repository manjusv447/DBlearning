# %%
df=spark.read.table("dev.ambika.cvsdata")

# 30 sec

# %%
df.display()

# %%
df.explain()

# %%
df1=df.

df1.cache()
# 1 mins

#2 seconds

# %%
df2=df1.

# 20 sec

# %%
df2.display()

# %%
df.display()

# %%
spark 4 

OOM

join 
group by 

skew 

cache (memeory) and persisit (disk or memory )

1. broadcast join
2. salting technique
