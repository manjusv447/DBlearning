-- %% [markdown]
-- ![](/Volumes/dev/naval/raw/object-model.png)

-- %%
use catalog dev;
use schema naval

-- %%
--use catalog dev;
create schema if not exists dev.naval;

-- %%
create or replace table dev.naval.demo (id int primary key, name string)

-- %%
insert into dev.naval.demo values(1,'Naval'), (1,'Unni')

-- %%
select * from dev.naval.demo

-- %%
Task:
1.Create schema with your name in dev catalog
2. create table in your schema
