# %% [markdown]
# ## Getting started

# %%
# %python
print("hello world ")

# %%
# %sql
select * from

# %% [markdown]
# ### Types of computes
# 1. All purpose
# 2. Job
# 3. Serverless notebooks
# 4. SQL warehoues

# %%
# %sql
select "Run SQl"

# %%
# %sql
select * from samples.tpch.orders

# %%
# %sql
select o_orderpriority, count(*) as order_count
from samples.tpch.orders
group by o_orderpriority
# Out:
# Databricks visualization. Run in Databricks to view.
