-- %%
create table if not exists dev.naval.sales_copy

-- %%
COPY INTO dev.naval.sales_copy 
FROM '/Volumes/dev/naval/project/sales/'
FILEFORMAT = CSV
FORMAT_OPTIONS ('mergeSchema' = 'true','header' = 'true')
COPY_OPTIONS ('mergeSchema' = 'true');
