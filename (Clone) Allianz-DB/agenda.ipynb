# %%
databricks sql ( ai features ) bi, self services feature (done)
databricks repo, cli command)
connect to power bi 
unity catalog
pipeline end to end
dabs cicd
project (pipeline, jobs, uc, cicd )

github action
delta sharing
lakehouse federation 
spark optmization

certification tip and tricks

# %%
pipeline end to end
1. manual
2. genie code
