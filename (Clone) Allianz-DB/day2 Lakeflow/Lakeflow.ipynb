-- %%
Lakeflow (ingestiong to databricks):
1. lakeflow connect
2. lakeflow pipeline
3. lakeflow jobs

-- %%
1. Lakeflow connect-- Ingestion

I) Cloud Object storage (S3, ADLS, GCS, Volume)
Volume:
csv,json,parquet, avro, txt, pdf, excel, xml, xls...etc

a. Batch 
          pyspark=== df 
          sql ==== CTAS
          UI

b. Incremental: "COPY INTO"

c. Streaming : Copy into, structured streaming, autoloader




structured streamin , autoloader
pyspark, streaming concept, triggers, checkpoints etc etc 



lakeflow spark declerative pipelines : open source
(formly Delta live table): batch, increaemnt, stremaig, autoloader -- sql or python 



II) Saas, DB, DW
-- Databricks Connector (Native)
-- Fivetran connector (200+ source )
